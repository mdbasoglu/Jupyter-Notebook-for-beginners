# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#An der Hochschule Paderborn wurde im Fach Statistik eine Klausur geschrieben.
#In einer Klausur, bei der maximal 40 Punkte erreicht werden konnten, nahmen 100 Studierende teil.

# a) Ergänzen Sie für die Punkte und die Noten folgende Angaben:

liste=np.loadtxt("PunkteUndNoten.txt")
liste
# Out:
# array([[17. , 21. , 15. , 20. , 24. , 29. , 27. , 28. , 28. , 23. ,  7. ,
#         27. , 28. , 27. , 22. , 26. , 23. , 21. , 27. , 22. , 25. , 20. ,
#         21. , 16. , 19. , 23. , 26. , 18. , 25. , 23. , 32. , 27. , 23. ,
#         22. , 27. , 28. , 31. , 26. , 32. , 28. , 27. , 20. , 23. , 19. ,
#         33. , 19. , 21. , 25. , 26. , 27. , 27. , 25. , 24. , 16. , 23. ,
#         34. , 22. , 25. , 15. , 32. , 23. , 29. , 26. , 26. , 24. , 23. ,
#         24. , 28. , 24. , 22. , 28. , 17. , 28. , 27. , 25. , 33. , 28. ,
#         22. , 20. , 14. , 26. , 25. , 21. , 17. , 23. , 29. , 32. , 26. ,
#         23. , 23. , 30. , 26. , 32. , 29. , 19. , 26. , 26. , 36. , 24. ,
#         29. ],
#        [ 5. ,  4.3,  5. ,  4.3,  4. ,  3. ,  3.3,  3.3,  3.3,  4. ,  6. ,
#          3.3,  3.3,  3.3,  4. ,  3.7,  4. ,  4.3,  3.3,  4. ,  4. ,  4.3,
#          4.3,  5. ,  4.7,  4. ,  3.7,  4.7,  4. ,  4. ,  2.3,  3.3,  4. ,
#          4. ,  3.3,  3.3,  2.7,  3.7,  2.3,  3.3,  3.3,  4.3,  4. ,  4.7,
#          2.3,  4.7,  4.3,  4. ,  3.7,  3.3,  3.3,  4. ,  4. ,  5. ,  4. ,
#          2. ,  4. ,  4. ,  5. ,  2.3,  4. ,  3. ,  3.7,  3.7,  4. ,  4. ,
#          4. ,  3.3,  4. ,  4. ,  3.3,  5. ,  3.3,  3.3,  4. ,  2.3,  3.3,
#          4. ,  4.3,  5. ,  3.7,  4. ,  4.3,  5. ,  4. ,  3. ,  2.3,  3.7,
#          4. ,  4. ,  3. ,  3.7,  2.3,  3. ,  4.7,  3.7,  3.7,  1.7,  4. ,
#          3. ]])

# %%
print("0.25 Quantil->", np.quantile(liste[0],0.25))
print("0.50 Quantil->",np.quantile(liste[0],0.50))
print("0.75 Quantil->",np.quantile(liste[0],0.75))

print("---------------------")

print("0.25 Quantil->", np.quantile(liste[1],0.25))
print("0.50 Quantil->",np.quantile(liste[1],0.50))
print("0.75 Quantil->",np.quantile(liste[1],0.75))
# Out:
# 0.25 Quantil-> 22.0
# 0.50 Quantil-> 25.0
# 0.75 Quantil-> 27.25
# ---------------------
# 0.25 Quantil-> 3.3
# 0.50 Quantil-> 4.0
# 0.75 Quantil-> 4.0

# %%
plt.hist(liste)
plt.yticks()
plt.grid()
plt.title("Empirische Verteilungsfunktion für Klausuren")
plt.ylabel(liste[0],"Punkte von 40")
plt.xlabel("Punkte von 7")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16380/984784877.py in <module>
#       3 plt.grid()
#       4 plt.title("Empirische Verteilungsfunktion für Klausuren")
# ----> 5 plt.ylabel(liste[0],"Punkte von 40")
#       6 plt.xlabel("Punkte von 7")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in ylabel(ylabel, fontdict, labelpad, loc, **kwargs)
#    3300 @_copy_docstring_and_deprecators(Axes.set_ylabel)
#    3301 def ylabel(ylabel, fontdict=None, labelpad=None, *, loc=None, **kwargs):
# -> 3302     return gca().set_ylabel(
#    3303         ylabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
#    3304         **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_ylabel(self, ylabel, fontdict, labelpad, loc, **kwargs)
#    3680         elif loc == 'top':
#    3681             kwargs.update(y=1, horizontalalignment='right')
# -> 3682         return self.yaxis.set_label_text(ylabel, fontdict, **kwargs)
#    3683
#    3684     def invert_yaxis(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1562         self.label.set_text(label)
#    1563         if fontdict is not None:
# -> 1564             self.label.update(fontdict)
#    1565         self.label.update(kwargs)
#    1566         self.stale = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     174         # docstring inherited
#     175         # make a copy so we do not mutate user input!
# --> 176         kwargs = dict(kwargs)
#     177         sentinel = object()  # bbox can be None, so use another sentinel.
#     178         # Update fontproperties first, as it has lowest priority.
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required
