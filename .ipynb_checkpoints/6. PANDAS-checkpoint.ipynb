# %% [markdown]
# # PANDAS

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Pandas Beispiel Titanic

# %%
df=pd.read_excel("TitanicDirty.xlsx")
df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                             Mr. Owen Harris Braund
# 1         1.0     1.0  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1.0     3.0                              Miss. Laina Heikkinen
# 3         NaN     NaN                                                NaN
# 4         1.0     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
# ..        ...     ...                                                ...
# 886       0.0     2.0                               Rev. Juozas Montvila
# 887       1.0     1.0                        Miss. Margaret Edith Graham
# 888       0.0     3.0                     Miss. Catherine Helen Johnston
# 889       1.0     1.0                               Mr. Karl Howell Behr
# 890       0.0     3.0                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 889 non-null    float64
#  1   Pclass                   889 non-null    float64
#  2   Name                     889 non-null    object
#  3   Sex                      889 non-null    object
#  4   Age                      889 non-null    float64
#  5   Siblings/Spouses Aboard  889 non-null    float64
#  6   Parents/Children Aboard  889 non-null    float64
#  7   Fare                     889 non-null    float64
#  8   Parentstext              889 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 62.8+ KB

# %%
#statischtisher Überblick über Zahlenwerte

df.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  889.000000  889.000000  889.000000               889.000000
# mean     0.386952    2.302587   29.483881                 0.526434
# std      0.487327    0.838008   14.108431                 1.103653
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.500000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard        Fare  Parentstext
# count               889.000000  889.000000   889.000000
# mean                  0.382452   32.352202     0.382452
# std                   0.806761   49.735718     0.806761
# min                   0.000000    0.000000     0.000000
# 25%                   0.000000    7.925000     0.000000
# ...

# %%
# Zugriff / Anzeige der Spalten

df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare', 'Parentstext'],
#       dtype='object')

# %%
for c in df.columns:
    print("Spalte",c)
# Out:
# Spalte Survived
# Spalte Pclass
# Spalte Name
# Spalte Sex
# Spalte Age
# Spalte Siblings/Spouses Aboard
# Spalte Parents/Children Aboard
# Spalte Fare
# Spalte Parentstext

# %% [markdown]
# ## Daten Reinigen

# %% [markdown]
# #### Nullwerte finden

# %%
#Gibt es in der Tabelle NULLWERTE?

df.isna()
# Out:
#      Survived  Pclass   Name    Sex    Age  Siblings/Spouses Aboard  \
# 0       False   False  False  False  False                    False
# 1       False   False  False  False  False                    False
# 2       False   False  False  False  False                    False
# 3        True    True   True   True   True                     True
# 4       False   False  False  False  False                    False
# ..        ...     ...    ...    ...    ...                      ...
# 886     False   False  False  False  False                    False
# 887     False   False  False  False  False                    False
# 888     False   False  False  False  False                    False
# 889     False   False  False  False  False                    False
# 890     False   False  False  False  False                    False
#
#      Parents/Children Aboard   Fare  Parentstext
# 0                      False  False        False
# 1                      False  False        False
# ...

# %%
df.isna().sum()
# Out:
# Survived                   2
# Pclass                     2
# Name                       2
# Sex                        2
# Age                        2
# Siblings/Spouses Aboard    2
# Parents/Children Aboard    2
# Fare                       2
# Parentstext                2
# dtype: int64

# %%
#Entferne Null-Werte

df.dropna(how='all')
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                             Mr. Owen Harris Braund
# 1         1.0     1.0  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1.0     3.0                              Miss. Laina Heikkinen
# 4         1.0     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 5         1.0     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
# ..        ...     ...                                                ...
# 886       0.0     2.0                               Rev. Juozas Montvila
# 887       1.0     1.0                        Miss. Margaret Edith Graham
# 888       0.0     3.0                     Miss. Catherine Helen Johnston
# 889       1.0     1.0                               Mr. Karl Howell Behr
# 890       0.0     3.0                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# ...

# %%
df.dropna(how='all',inplace=True)
df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                             Mr. Owen Harris Braund
# 1         1.0     1.0  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1.0     3.0                              Miss. Laina Heikkinen
# 4         1.0     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 5         1.0     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
# ..        ...     ...                                                ...
# 886       0.0     2.0                               Rev. Juozas Montvila
# 887       1.0     1.0                        Miss. Margaret Edith Graham
# 888       0.0     3.0                     Miss. Catherine Helen Johnston
# 889       1.0     1.0                               Mr. Karl Howell Behr
# 890       0.0     3.0                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# ...

# %% [markdown]
# ### Duplikate entfernen

# %%
#Gibt es Duplikate?

df.duplicated()
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0     3.0                             Mr. Owen Harris Braund
# 1       1.0     1.0  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2       1.0     3.0                              Miss. Laina Heikkinen
# 4       1.0     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 5       1.0     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# 0    male  22.0                      1.0                      0.0   7.2500
# 1  female  38.0                      1.0                      0.0  71.2833
# 2  female  26.0                      0.0                      0.0   7.9250
# 4  female  35.0                      1.0                      0.0  53.1000
# 5  female  35.0                      1.0                      0.0  53.1000
#
#    Parentstext
# 0          0.0
# 1          0.0
# 2          0.0
# 4          0.0
# ...

# %%
df.duplicated().sum()
# Out:
# 2

# %%
#Lösche Duplikate

df.drop_duplicates(inplace=True)
df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                             Mr. Owen Harris Braund
# 1         1.0     1.0  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1.0     3.0                              Miss. Laina Heikkinen
# 4         1.0     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 7         0.0     3.0                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 886       0.0     2.0                               Rev. Juozas Montvila
# 887       1.0     1.0                        Miss. Margaret Edith Graham
# 888       0.0     3.0                     Miss. Catherine Helen Johnston
# 889       1.0     1.0                               Mr. Karl Howell Behr
# 890       0.0     3.0                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# ...

# %% [markdown]
# ### Dtentypen korrigieren

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 887 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    float64
#  1   Pclass                   887 non-null    float64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    float64
#  6   Parents/Children Aboard  887 non-null    float64
#  7   Fare                     887 non-null    float64
#  8   Parentstext              887 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 69.3+ KB

# %%
df["Survived"]
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 4      1.0
# 7      0.0
#       ...
# 886    0.0
# 887    1.0
# 888    0.0
# 889    1.0
# 890    0.0
# Name: Survived, Length: 887, dtype: float64

# %%
df["Survived"].unique()
# Out:
# array([0., 1.])

# %%
for c in df.columns:
    print(df[c].unique())
# Out:
# [0. 1.]
# [3. 1. 2.]
# ['Mr. Owen Harris Braund'
#  'Mrs. John Bradley (Florence Briggs Thayer) Cumings'
#  'Miss. Laina Heikkinen' 'Mrs. Jacques Heath (Lily May Peel) Futrelle'
#  'Mr. William Henry Allen' 'Mr. James Moran' 'Mr. Timothy J McCarthy'
#  'Master. Gosta Leonard Palsson'
#  'Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson'
#  'Mrs. Nicholas (Adele Achem) Nasser' 'Miss. Marguerite Rut Sandstrom'
#  'Miss. Elizabeth Bonnell' 'Mr. William Henry Saundercock'
#  'Mr. Anders Johan Andersson' 'Miss. Hulda Amanda Adolfina Vestrom'
#  'Mrs. (Mary D Kingcome) Hewlett' 'Master. Eugene Rice'
#  'Mr. Charles Eugene Williams'
#  'Mrs. Julius (Emelia Maria Vandemoortele) Vander Planke'
#  'Mrs. Fatima Masselmani' 'Mr. Joseph J Fynney' 'Mr. Lawrence Beesley'
#  'Miss. Anna McGowan' 'Mr. William Thompson Sloper'
#  'Miss. Torborg Danira Palsson'
#  'Mrs. Carl Oscar (Selma Augusta Emilia Johansson) Asplund'
#  'Mr. Farred Chehab Emir' 'Mr. Charles Alexander Fortune'
# ...

# %%
for c in df.columns:
    if c!="Name":
        print("Spalte:",c,"hat die Werte: ", df[c].unique())
# Out:
# Spalte: Survived hat die Werte:  [0. 1.]
# Spalte: Pclass hat die Werte:  [3. 1. 2.]
# Spalte: Sex hat die Werte:  ['male' 'female']
# Spalte: Age hat die Werte:  [22.   38.   26.   35.   27.   54.    2.   14.    4.   58.   20.   39.
#  55.   23.   31.   34.   15.   28.    8.   19.   24.   40.   48.   18.
#  66.   42.   21.    3.   30.   16.    7.   49.   29.   65.   46.   28.5
#   5.   11.   45.   64.   17.   32.   25.    0.83 33.   59.   71.   37.
#  47.   14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.
#  60.   61.   56.   50.   36.   45.5  20.5  62.   41.   52.   63.   57.
#  23.5   0.92 43.   10.   13.    0.75 69.   53.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]
# Spalte: Siblings/Spouses Aboard hat die Werte:  [1. 0. 3. 4. 2. 5. 8.]
# Spalte: Parents/Children Aboard hat die Werte:  [0. 1. 2. 5. 3. 4. 6.]
# Spalte: Fare hat die Werte:  [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
# ...

# %%
#Datentyp von "Age"

df["Age"].dtype
# Out:
# dtype('float64')

# %%
df["Age"].astype("int16")
# Out:
# 0      22
# 1      38
# 2      26
# 4      35
# 7      35
#        ..
# 886    27
# 887    19
# 888     7
# 889    26
# 890    32
# Name: Age, Length: 887, dtype: int16

# %%
df["Age"]=df["Age"].astype("int16")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 887 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    float64
#  1   Pclass                   887 non-null    float64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    int16
#  5   Siblings/Spouses Aboard  887 non-null    float64
#  6   Parents/Children Aboard  887 non-null    float64
#  7   Fare                     887 non-null    float64
#  8   Parentstext              887 non-null    float64
# dtypes: float64(6), int16(1), object(2)
# memory usage: 64.1+ KB

# %%
df["Age"].unique()
# Out:
# array([22, 38, 26, 35, 27, 54,  2, 14,  4, 58, 20, 39, 55, 23, 31, 34, 15,
#        28,  8, 19, 24, 40, 48, 18, 66, 42, 21,  3, 30, 16,  7, 49, 29, 65,
#        46,  5, 11, 45, 64, 17, 32, 25,  0, 33, 59, 71, 37, 47, 70, 12,  9,
#        36, 51, 44,  1, 60, 61, 56, 50, 62, 41, 52, 63, 57, 43, 10, 13, 69,
#        53, 80,  6, 74], dtype=int16)

# %%
df["Survived"]=df["Survived"].astype("int16")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 887 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int16
#  1   Pclass                   887 non-null    float64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    int16
#  5   Siblings/Spouses Aboard  887 non-null    float64
#  6   Parents/Children Aboard  887 non-null    float64
#  7   Fare                     887 non-null    float64
#  8   Parentstext              887 non-null    float64
# dtypes: float64(5), int16(2), object(2)
# memory usage: 58.9+ KB

# %%
#Datentype ändern

df.astype({'Age':'int16','Survived':'int16','Pclass':'int16'}).dtypes #icer yazilan spaltenin tipini degistik
# Out:
# Survived                     int16
# Pclass                       int16
# Name                        object
# Sex                         object
# Age                          int16
# Siblings/Spouses Aboard    float64
# Parents/Children Aboard    float64
# Fare                       float64
# Parentstext                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 887 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int16
#  1   Pclass                   887 non-null    float64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    int16
#  5   Siblings/Spouses Aboard  887 non-null    float64
#  6   Parents/Children Aboard  887 non-null    float64
#  7   Fare                     887 non-null    float64
#  8   Parentstext              887 non-null    float64
# dtypes: float64(5), int16(2), object(2)
# memory usage: 58.9+ KB

# %% [markdown]
# # Erste Informationen

# %%
# Alle Namen Anzeigen(Werte einer Spalte)

df["Name"]
# Out:
# 0                                 Mr. Owen Harris Braund
# 1      Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2                                  Miss. Laina Heikkinen
# 4            Mrs. Jacques Heath (Lily May Peel) Futrelle
# 7                                Mr. William Henry Allen
#                              ...
# 886                                 Rev. Juozas Montvila
# 887                          Miss. Margaret Edith Graham
# 888                       Miss. Catherine Helen Johnston
# 889                                 Mr. Karl Howell Behr
# 890                                   Mr. Patrick Dooley
# Name: Name, Length: 887, dtype: object

# %%
#Ersten 10 Namen anzegen

df["Name"].head(10)
df["Name"][0:10]
df.loc[0:10,"Name"]
# Out:
# 0                                Mr. Owen Harris Braund
# 1     Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2                                 Miss. Laina Heikkinen
# 4           Mrs. Jacques Heath (Lily May Peel) Futrelle
# 7                               Mr. William Henry Allen
# 8                                       Mr. James Moran
# 9                                Mr. Timothy J McCarthy
# 10                        Master. Gosta Leonard Palsson
# Name: Name, dtype: object

# %%
#'Zugriff auf einzelne Elemente mit .loc

df.loc[99,"Name"] #lesender Zugriff
# Out:
# 'Mr. George B Goldschmidt'

# %%
df.loc[99,"Name"]="Leonardo Di Caprio" # Burada yazili olan ismi degistirdik

# %%
df.loc[99,"Name"]
# Out:
# 'Leonardo Di Caprio'

# %%
df.iloc[1,2]   # lesender Zugriff auf die 2. Zeile und 5. Spalte
# Out:
# 'Mrs. John Bradley (Florence Briggs Thayer) Cumings'

# %%
df.iloc[4,2] #lesender Zugriff auf die 5.Zeile und 3. Spalte
# Out:
# 'Mr. William Henry Allen'

# %%
df.iloc[4,2]="Woody Allan"
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0     3.0                             Mr. Owen Harris Braund
# 1           1     1.0  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1     3.0                              Miss. Laina Heikkinen
# 4           1     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 7           0     3.0                                        Woody Allan
# ..        ...     ...                                                ...
# 886         0     2.0                               Rev. Juozas Montvila
# 887         1     1.0                        Miss. Margaret Edith Graham
# 888         0     3.0                     Miss. Catherine Helen Johnston
# 889         1     1.0                               Mr. Karl Howell Behr
# 890         0     3.0                                 Mr. Patrick Dooley
#
#         Sex  Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# ...

# %%
df.iloc[:,2] #ganze 3. spalte ausgeben
# Out:
# 0                                 Mr. Owen Harris Braund
# 1      Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2                                  Miss. Laina Heikkinen
# 4            Mrs. Jacques Heath (Lily May Peel) Futrelle
# 7                                            Woody Allan
#                              ...
# 886                                 Rev. Juozas Montvila
# 887                          Miss. Margaret Edith Graham
# 888                       Miss. Catherine Helen Johnston
# 889                                 Mr. Karl Howell Behr
# 890                                   Mr. Patrick Dooley
# Name: Name, Length: 887, dtype: object

# %%
df.iloc[3,:] #ganze 4. zeile ausgeben
# Out:
# Survived                        1
# Pclass                        1.0
# Name                       Miller
# Sex                        female
# Age                            35
# Siblings/Spouses Aboard       1.0
# Parents/Children Aboard       0.0
# Fare                         53.1
# Parentstext                   0.0
# Name: 4, dtype: object

# %%
#Alle Frauen Finden


df["Sex"]=="female"  #liefert eine Series von boolischen Werten
df.loc[df["Sex"]=="female"]
# Out:
#      Survived  Pclass    Name     Sex  Age  Siblings/Spouses Aboard  \
# 1           1     1.0  Miller  female   38                      1.0
# 2           1     3.0  Miller  female   26                      0.0
# 4           1     1.0  Miller  female   35                      1.0
# 11          1     3.0  Miller  female   27                      0.0
# 13          1     2.0  Miller  female   14                      1.0
# ..        ...     ...     ...     ...  ...                      ...
# 880         1     2.0  Miller  female   25                      0.0
# 882         0     3.0  Miller  female   22                      0.0
# 885         0     3.0  Miller  female   39                      0.0
# 887         1     1.0  Miller  female   19                      0.0
# 888         0     3.0  Miller  female    7                      1.0
#
#      Parents/Children Aboard     Fare  Parentstext
# 1                        0.0  71.2833          0.0
# ...

# %%
#Alle überlebenden finden

df.loc[df["Survived"]==1]
# Out:
#      Survived  Pclass    Name     Sex  Age  Siblings/Spouses Aboard  \
# 1           1     1.0  Miller  female   38                      1.0
# 2           1     3.0  Miller  female   26                      0.0
# 4           1     1.0  Miller  female   35                      1.0
# 11          1     3.0  Miller  female   27                      0.0
# 13          1     2.0  Miller  female   14                      1.0
# ..        ...     ...     ...     ...  ...                      ...
# 875         1     3.0  Miller  female   15                      0.0
# 879         1     1.0  Miller  female   56                      0.0
# 880         1     2.0  Miller  female   25                      0.0
# 887         1     1.0  Miller  female   19                      0.0
# 889         1     1.0  Miller    male   26                      0.0
#
#      Parents/Children Aboard     Fare  Parentstext
# 1                        0.0  71.2833          0.0
# ...

# %%
df.loc[(df["Survived"]==1)&(df["Sex"]=="female")]
# Out:
#      Survived  Pclass    Name     Sex  Age  Siblings/Spouses Aboard  \
# 1           1     1.0  Miller  female   38                      1.0
# 2           1     3.0  Miller  female   26                      0.0
# 4           1     1.0  Miller  female   35                      1.0
# 11          1     3.0  Miller  female   27                      0.0
# 13          1     2.0  Miller  female   14                      1.0
# ..        ...     ...     ...     ...  ...                      ...
# 874         1     2.0  Miller  female   28                      1.0
# 875         1     3.0  Miller  female   15                      0.0
# 879         1     1.0  Miller  female   56                      0.0
# 880         1     2.0  Miller  female   25                      0.0
# 887         1     1.0  Miller  female   19                      0.0
#
#      Parents/Children Aboard     Fare  Parentstext
# 1                        0.0  71.2833          0.0
# ...

# %%
#Korrelation zwisschen den Variablen anzeigen

df.corr()
# Out:
#                          Survived    Pclass       Age  \
# Survived                 1.000000 -0.336528 -0.059665
# Pclass                  -0.336528  1.000000 -0.391572
# Age                     -0.059665 -0.391572  1.000000
# Siblings/Spouses Aboard -0.037082  0.085026 -0.297426
# Parents/Children Aboard  0.080097  0.020252 -0.193976
# Fare                     0.256179 -0.548919  0.112464
# Parentstext              0.080097  0.020252 -0.193976
#
#                          Siblings/Spouses Aboard  Parents/Children Aboard  \
# Survived                               -0.037082                 0.080097
# Pclass                                  0.085026                 0.020252
# Age                                    -0.297426                -0.193976
# Siblings/Spouses Aboard                 1.000000                 0.414244
# Parents/Children Aboard                 0.414244                 1.000000
# Fare                                    0.158839                 0.215470
# ...

# %%
#Einfügen einer neuen Spalte


df["SexN"]=0 #0 für Männer
df.loc[df["Sex"]=="female", "SexN"]=1
df.corr()
# Out:
#                          Survived    Pclass       Age  \
# Survived                 1.000000 -0.336528 -0.059665
# Pclass                  -0.336528  1.000000 -0.391572
# Age                     -0.059665 -0.391572  1.000000
# Siblings/Spouses Aboard -0.037082  0.085026 -0.297426
# Parents/Children Aboard  0.080097  0.020252 -0.193976
# Fare                     0.256179 -0.548919  0.112464
# Parentstext              0.080097  0.020252 -0.193976
# SexN                     0.542152 -0.129507 -0.091487
#
#                          Siblings/Spouses Aboard  Parents/Children Aboard  \
# Survived                               -0.037082                 0.080097
# Pclass                                  0.085026                 0.020252
# Age                                    -0.297426                -0.193976
# Siblings/Spouses Aboard                 1.000000                 0.414244
# Parents/Children Aboard                 0.414244                 1.000000
# ...
