# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv('top_100_movies_by_genres.csv')
df.head()
# Out:
#                 Genre  Rank RatingTomatometer  \
# 0  Action & Adventure   1.0               96%
# 1  Action & Adventure   2.0               94%
# 2  Action & Adventure   3.0               97%
# 3  Action & Adventure   4.0               97%
# 4  Action & Adventure   5.0               97%
#
#                                       Title  No. of Reviews
# 0                      Black Panther (2018)             525
# 1                  Avengers: Endgame (2019)             547
# 2      Mission: Impossible - Fallout (2018)             437
# 3                 Mad Max: Fury Road (2015)             434
# 4  Spider-Man: Into the Spider-Verse (2018)             393

# %%
df['Genre'].value_counts()
# Out:
# Action & Adventure           100
# Animation                    100
# Special Interest             100
# Science Fiction & Fantasy    100
# Romance                      100
# Mystery & Suspense           100
# Musical & Performing Arts    100
# Kids & Family                100
# Horror                       100
# Drama                        100
# Documentary                  100
# Comedy                       100
# Classics                     100
# Art House & International    100
# Western                       86
# Sports & Fitness              69
# Television                    57
# Name: Genre, dtype: int64

# %%
df['Title'].value_counts().head(10)
# Out:
# Miracle on 34th Street (1947)                           5
# Beauty and the Beast (1991)                             5
# Metropolis (1927)                                       5
# Afghan Star (2009)                                      5
# Harry Potter and the Deathly Hallows - Part 2 (2011)    5
# 101 Dalmatians (1961)                                   5
# Toy Story 4 (2019)                                      4
# Amy (2015)                                              4
# The LEGO Movie (2014)                                   4
# Top Hat (1935)                                          4
# Name: Title, dtype: int64

# %%
df[df['Rank'] == 1.0]
# Out:
#                           Genre  Rank  RatingTomatometer  \
# 0            Action & Adventure   1.0               0.96
# 100                   Animation   1.0               0.97
# 200   Art House & International   1.0               0.98
# 300                    Classics   1.0               0.99
# 400                      Comedy   1.0               0.99
# 500                 Documentary   1.0               0.97
# 600                       Drama   1.0               0.99
# 700                      Horror   1.0               0.93
# 800               Kids & Family   1.0               0.98
# 900   Musical & Performing Arts   1.0               0.98
# 1000         Mystery & Suspense   1.0               0.99
# 1100                    Romance   1.0               0.99
# 1200  Science Fiction & Fantasy   1.0               0.98
# 1300           Special Interest   1.0               0.98
# 1400           Sports & Fitness   1.0               0.98
# ...

# %%
df[df['Rank'] == 5.0]
# Out:
#                           Genre  Rank  RatingTomatometer  \
# 4            Action & Adventure   5.0               0.97
# 104                   Animation   5.0               0.98
# 204   Art House & International   5.0               0.97
# 304                    Classics   5.0               0.99
# 404                      Comedy   5.0               0.96
# 504                 Documentary   5.0               0.98
# 604                       Drama   5.0               0.99
# 704                      Horror   5.0               0.92
# 804               Kids & Family   5.0               0.97
# 904   Musical & Performing Arts   5.0               0.91
# 1004         Mystery & Suspense   5.0               0.98
# 1104                    Romance   5.0               0.92
# 1204  Science Fiction & Fantasy   5.0               0.97
# 1304           Special Interest   5.0               0.94
# 1404           Sports & Fitness   5.0               0.97
# ...

# %%
df[df['RatingTomatometer'] == 0.99]
# Out:
#                    Genre  Rank  RatingTomatometer  \
# 47    Action & Adventure  48.0               0.99
# 48    Action & Adventure  49.0               0.99
# 108            Animation   9.0               0.99
# 113            Animation  14.0               0.99
# 120            Animation  21.0               0.99
# ...                  ...   ...                ...
# 1316    Special Interest  17.0               0.99
# 1320    Special Interest  21.0               0.99
# 1324    Special Interest  25.0               0.99
# 1325    Special Interest  26.0               0.99
# 1326    Special Interest  27.0               0.99
#
#                                 Title  No. of Reviews
# 47                 Wolfwalkers (2020)             162
# 48                  Goldfinger (1964)              69
# 108               Paddington 2 (2018)             247
# 113               Finding Nemo (2003)             269
# 120                Wolfwalkers (2020)             162
# ...

# %%
df.describe()
# Out:
#               Rank  No. of Reviews
# count  1612.000000     1612.000000
# mean     48.702854      148.065136
# std      28.453613      120.011877
# min       1.000000       40.000000
# 25%      24.000000       58.000000
# 50%      48.000000       95.500000
# 75%      73.000000      212.500000
# max     100.000000      571.000000

# %%
df.info()
# df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612 entries, 0 to 1611
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Genre              1612 non-null   object
#  1   Rank               1612 non-null   float64
#  2   RatingTomatometer  1612 non-null   object
#  3   Title              1612 non-null   object
#  4   No. of Reviews     1612 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 63.1+ KB

# %%
#Nullwerte
df.isna().sum()
# Out:
# Genre                0
# Rank                 0
# RatingTomatometer    0
# Title                0
# No. of Reviews       0
# dtype: int64

# %%
avg_num_reviews = df[['Genre', 'No. of Reviews']].groupby('Genre').mean()
avg_num_reviews.plot.bar(title='Average number of reviews by Genre')
# Out:
# <AxesSubplot:title={'center':'Average number of reviews by Genre'}, xlabel='Genre'>

# %%
import seaborn as sns
pairplot_figure = sns.pairplot(df,hue="Genre")
pairplot_figure.fig.set_size_inches(15,10)

# %%
df['RatingTomatometer'] = df['RatingTomatometer'].apply(lambda value: (float(value.strip('%'))/100))
df.head()
# Out:
#                 Genre  Rank  RatingTomatometer  \
# 0  Action & Adventure   1.0               0.96
# 1  Action & Adventure   2.0               0.94
# 2  Action & Adventure   3.0               0.97
# 3  Action & Adventure   4.0               0.97
# 4  Action & Adventure   5.0               0.97
#
#                                       Title  No. of Reviews
# 0                      Black Panther (2018)             525
# 1                  Avengers: Endgame (2019)             547
# 2      Mission: Impossible - Fallout (2018)             437
# 3                 Mad Max: Fury Road (2015)             434
# 4  Spider-Man: Into the Spider-Verse (2018)             393

# %%
avg_tomatoemeter_rating = df[['Genre', 'RatingTomatometer']].groupby('Genre').mean()
avg_tomatoemeter_rating.plot.bar(title='Average number of reviews by Rating Tomatometer')
# Out:
# <AxesSubplot:title={'center':'Average number of reviews by Rating Tomatometer'}, xlabel='Genre'>

# %%
genre_count = df.value_counts('Genre')
genre_count.plot.bar(title='Genre Count')
# Out:
# <AxesSubplot:title={'center':'Genre Count'}, xlabel='Genre'>

# %%
genre_count = df.value_counts('Title')
genre_count.plot.bar(title='Title Count')
# Out:
# <AxesSubplot:title={'center':'Title Count'}, xlabel='Title'>

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(14,6))
sns.scatterplot(x=df['No. of Reviews'], y=df['RatingTomatometer']);
